# %%
from pathlib import Path
import pandas as pd
from tqdm.notebook import tqdm 
from datetime import  datetime, timedelta
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter, MonthLocator

# %%
path = Path('W:') / 'Amber Ag' / 'Amber clean data'

# %%
filename = path / 'Bin_5_simulation_start.xlsx'
df = pd.read_excel(filename)

# %%
df
# Out:
#       Storage time (hrs) OPI_DATE  MC1_Avg_5_sensors                    Date  \
# 0                    NaN      NaT                NaN 2020-11-03 02:34:00.000
# 1                    NaN      NaT                NaN 2020-11-03 03:34:00.000
# 2                    NaN      NaT                NaN 2020-11-03 04:34:00.000
# 3                    NaN      NaT                NaN 2020-11-03 05:34:00.000
# 4                    NaN      NaT                NaN 2020-11-03 06:34:00.000
# ...                  ...      ...                ...                     ...
# 6104              6104.0      NaT                NaN 2021-07-15 10:20:57.195
# 6105              6105.0      NaT                NaN 2021-07-15 11:20:57.190
# 6106              6106.0      NaT                NaN 2021-07-15 12:20:57.185
# 6107              6107.0      NaT                NaN 2021-07-15 13:20:57.180
# 6108              6108.0      NaT                NaN 2021-07-15 14:20:57.175
#
# ...

# %%
for index, row in df.iterrows():
    if row['Date'] is pd.NaT:
        # print(df.loc[index-1, 'Date'] + timedelta(hours=1))
        df.loc[index, 'Date'] = df.loc[index-1, 'Date'] + timedelta(hours=1)

# %%
df['Date'] = df['Date'].apply(lambda x: datetime.strftime(x, '%m/%d/%Y %I:%M %p'))

# %%
#this not needed
df['Date'] = df['Date'].apply(lambda x: datetime.strftime(x, '%m/%d/%Y %I:%M %p') if x is not pd.NaT else x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_32396/76947878.py in <module>
# ----> 1 df['Date'] = df['Date'].apply(lambda x: datetime.strftime(x, '%m/%d/%Y %I:%M %p') if x is not pd.NaT else x)
#
# U:\pchome\.pcprefsBAD\AppData\Python\Python38\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4354         dtype: float64
#    4355         """
# -> 4356         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4357
#    4358     def _reduce(
#
# U:\pchome\.pcprefsBAD\AppData\Python\Python38\site-packages\pandas\core\apply.py in apply(self)
#    1034             return self.apply_str()
#    1035
# -> 1036         return self.apply_standard()
#    1037
#    1038     def agg(self):
#
# ...

# %%
df.to_excel(path / 'Bin_5_simulation_start_temp.xlsx', index=False)
