# %%
from pathlib import Path
import pandas as pd
from tqdm.notebook import tqdm 
from datetime import  datetime, timedelta
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter, MonthLocator

# %%
# Set the directory
# Use this code for plotting the graphs of OPI data after the inital clean up
# Ensure the excel files as CVS delimited
#Ensure to specify the date range for the plot in the last two lines of this code
path = Path('U:') / 'Opi system file' / 'OPI CO2 Nov3 2020'

# %%
# Original file name
filename = path / 'CO2 3Nov 2020 Bin13.csv'

# %%
# Load file into Pandas data frame
df = pd.read_csv(filename)
df
# Out:
#              Date_CO2  CO2_Plenum  CO2_Headspace     Date_Ambient  \
# 0     11/6/2020 15:44    0.536337       0.528224  11/6/2020 16:00
# 1     11/6/2020 16:44    0.545077       0.501610  11/6/2020 17:00
# 2     11/6/2020 17:44    0.533929       0.512470  11/6/2020 18:00
# 3     11/6/2020 18:44    0.563265       0.493393  11/6/2020 19:00
# 4     11/6/2020 19:44    0.557900       0.502317  11/6/2020 20:00
# ...               ...         ...            ...              ...
# 3052              NaN         NaN            NaN  3/13/2021 20:00
# 3053              NaN         NaN            NaN  3/13/2021 21:00
# 3054              NaN         NaN            NaN  3/13/2021 22:00
# 3055              NaN         NaN            NaN  3/13/2021 23:00
# 3056              NaN         NaN            NaN   3/14/2021 0:00
#
#       Temp_Ambient  RH_Ambient       Date_Grain  Grain_Avg_Temp  Grain_Avg_RH
# 0            72.75       70.17  11/6/2020 16:14       64.941667     66.816667
# 1            71.46       71.29  11/6/2020 17:14       63.704167     68.283333
# 2            66.53       73.98  11/6/2020 18:15       58.838889     72.466667
# 3            62.24       75.76  11/6/2020 19:15       54.777778     76.383333
# 4            59.75       79.23  11/6/2020 20:15       53.879167     78.233333
# ...            ...         ...              ...             ...           ...
# 3052         46.03       38.65              NaN             NaN           NaN
# 3053         42.10       43.93              NaN             NaN           NaN
# 3054         41.25       47.20              NaN             NaN           NaN
# 3055         38.88       48.17              NaN             NaN           NaN
# 3056         37.79       54.06              NaN             NaN           NaN
#
# [3057 rows x 9 columns]

# %%
# Change the date format
for index, row in tqdm(df.iterrows()):

    # Remove unnecasy charactor
    timestamp_text = row.Date_CO2
    try:
        # Convert to Python datetime variable
        timestamp = datetime.strptime(timestamp_text, '%m/%d/%Y %H:%M')
        # Replace the old data
        df.at[index, 'Date_CO2'] = timestamp
    except:
        pass

# View new version
df
# Out:
# 0it [00:00, ?it/s]
#                  Date_CO2  CO2_Plenum  CO2_Headspace     Date_Ambient  \
# 0     2020-11-06 15:44:00    0.536337       0.528224  11/6/2020 16:00
# 1     2020-11-06 16:44:00    0.545077       0.501610  11/6/2020 17:00
# 2     2020-11-06 17:44:00    0.533929       0.512470  11/6/2020 18:00
# 3     2020-11-06 18:44:00    0.563265       0.493393  11/6/2020 19:00
# 4     2020-11-06 19:44:00    0.557900       0.502317  11/6/2020 20:00
# ...                   ...         ...            ...              ...
# 3052                  NaN         NaN            NaN  3/13/2021 20:00
# 3053                  NaN         NaN            NaN  3/13/2021 21:00
# 3054                  NaN         NaN            NaN  3/13/2021 22:00
# 3055                  NaN         NaN            NaN  3/13/2021 23:00
# 3056                  NaN         NaN            NaN   3/14/2021 0:00
#
#       Temp_Ambient  RH_Ambient       Date_Grain  Grain_Avg_Temp  Grain_Avg_RH
# 0            72.75       70.17  11/6/2020 16:14       64.941667     66.816667
# 1            71.46       71.29  11/6/2020 17:14       63.704167     68.283333
# 2            66.53       73.98  11/6/2020 18:15       58.838889     72.466667
# 3            62.24       75.76  11/6/2020 19:15       54.777778     76.383333
# 4            59.75       79.23  11/6/2020 20:15       53.879167     78.233333
# ...            ...         ...              ...             ...           ...
# 3052         46.03       38.65              NaN             NaN           NaN
# 3053         42.10       43.93              NaN             NaN           NaN
# 3054         41.25       47.20              NaN             NaN           NaN
# 3055         38.88       48.17              NaN             NaN           NaN
# 3056         37.79       54.06              NaN             NaN           NaN
#
# [3057 rows x 9 columns]

# %%
# Change the date format
for index, row in tqdm(df.iterrows()):

    # Remove unnecasy charactor
    timestamp_text = row.Date_Ambient
    try:
        # Convert to Python datetime variable
        timestamp = datetime.strptime(timestamp_text, '%m/%d/%Y %H:%M')
        # Replace the old data
        df.at[index, 'Date_Ambient'] = timestamp
    except:
        pass

# View new version
df
# Out:
# 0it [00:00, ?it/s]
#                  Date_CO2  CO2_Plenum  CO2_Headspace         Date_Ambient  \
# 0     2020-11-06 15:44:00    0.536337       0.528224  2020-11-06 16:00:00
# 1     2020-11-06 16:44:00    0.545077       0.501610  2020-11-06 17:00:00
# 2     2020-11-06 17:44:00    0.533929       0.512470  2020-11-06 18:00:00
# 3     2020-11-06 18:44:00    0.563265       0.493393  2020-11-06 19:00:00
# 4     2020-11-06 19:44:00    0.557900       0.502317  2020-11-06 20:00:00
# ...                   ...         ...            ...                  ...
# 3052                  NaN         NaN            NaN  2021-03-13 20:00:00
# 3053                  NaN         NaN            NaN  2021-03-13 21:00:00
# 3054                  NaN         NaN            NaN  2021-03-13 22:00:00
# 3055                  NaN         NaN            NaN  2021-03-13 23:00:00
# 3056                  NaN         NaN            NaN  2021-03-14 00:00:00
#
#       Temp_Ambient  RH_Ambient       Date_Grain  Grain_Avg_Temp  Grain_Avg_RH
# 0            72.75       70.17  11/6/2020 16:14       64.941667     66.816667
# 1            71.46       71.29  11/6/2020 17:14       63.704167     68.283333
# 2            66.53       73.98  11/6/2020 18:15       58.838889     72.466667
# 3            62.24       75.76  11/6/2020 19:15       54.777778     76.383333
# 4            59.75       79.23  11/6/2020 20:15       53.879167     78.233333
# ...            ...         ...              ...             ...           ...
# 3052         46.03       38.65              NaN             NaN           NaN
# 3053         42.10       43.93              NaN             NaN           NaN
# 3054         41.25       47.20              NaN             NaN           NaN
# 3055         38.88       48.17              NaN             NaN           NaN
# 3056         37.79       54.06              NaN             NaN           NaN
#
# [3057 rows x 9 columns]

# %%
# Change the date format
for index, row in tqdm(df.iterrows()):

    # Remove unnecasy charactor
    timestamp_text = row.Date_Grain
    try:
        # Convert to Python datetime variable
        timestamp = datetime.strptime(timestamp_text, '%m/%d/%Y %H:%M')
        # Replace the old data
        df.at[index, 'Date_Grain'] = timestamp
    except:
        pass

# View new version
df
# Out:
# 0it [00:00, ?it/s]
#                  Date_CO2  CO2_Plenum  CO2_Headspace         Date_Ambient  \
# 0     2020-11-06 15:44:00    0.536337       0.528224  2020-11-06 16:00:00
# 1     2020-11-06 16:44:00    0.545077       0.501610  2020-11-06 17:00:00
# 2     2020-11-06 17:44:00    0.533929       0.512470  2020-11-06 18:00:00
# 3     2020-11-06 18:44:00    0.563265       0.493393  2020-11-06 19:00:00
# 4     2020-11-06 19:44:00    0.557900       0.502317  2020-11-06 20:00:00
# ...                   ...         ...            ...                  ...
# 3052                  NaN         NaN            NaN  2021-03-13 20:00:00
# 3053                  NaN         NaN            NaN  2021-03-13 21:00:00
# 3054                  NaN         NaN            NaN  2021-03-13 22:00:00
# 3055                  NaN         NaN            NaN  2021-03-13 23:00:00
# 3056                  NaN         NaN            NaN  2021-03-14 00:00:00
#
#       Temp_Ambient  RH_Ambient           Date_Grain  Grain_Avg_Temp  \
# 0            72.75       70.17  2020-11-06 16:14:00       64.941667
# 1            71.46       71.29  2020-11-06 17:14:00       63.704167
# 2            66.53       73.98  2020-11-06 18:15:00       58.838889
# 3            62.24       75.76  2020-11-06 19:15:00       54.777778
# 4            59.75       79.23  2020-11-06 20:15:00       53.879167
# ...            ...         ...                  ...             ...
# 3052         46.03       38.65                  NaN             NaN
# 3053         42.10       43.93                  NaN             NaN
# 3054         41.25       47.20                  NaN             NaN
# 3055         38.88       48.17                  NaN             NaN
# 3056         37.79       54.06                  NaN             NaN
#
#       Grain_Avg_RH
# 0        66.816667
# 1        68.283333
# 2        72.466667
# 3        76.383333
# 4        78.233333
# ...            ...
# 3052           NaN
# 3053           NaN
# 3054           NaN
# 3055           NaN
# 3056           NaN
#
# [3057 rows x 9 columns]

# %%
date_grain_df = df[['Date_Grain', 'Grain_Avg_Temp', 'Grain_Avg_RH']].copy()
date_grain_df
# Out:
#                Date_Grain  Grain_Avg_Temp  Grain_Avg_RH
# 0     2020-11-06 16:14:00       64.941667     66.816667
# 1     2020-11-06 17:14:00       63.704167     68.283333
# 2     2020-11-06 18:15:00       58.838889     72.466667
# 3     2020-11-06 19:15:00       54.777778     76.383333
# 4     2020-11-06 20:15:00       53.879167     78.233333
# ...                   ...             ...           ...
# 3052                  NaN             NaN           NaN
# 3053                  NaN             NaN           NaN
# 3054                  NaN             NaN           NaN
# 3055                  NaN             NaN           NaN
# 3056                  NaN             NaN           NaN
#
# [3057 rows x 3 columns]

# %%
date_grain_df = date_grain_df.dropna()
date_grain_df
# Out:
#                Date_Grain  Grain_Avg_Temp  Grain_Avg_RH
# 0     2020-11-06 16:14:00       64.941667     66.816667
# 1     2020-11-06 17:14:00       63.704167     68.283333
# 2     2020-11-06 18:15:00       58.838889     72.466667
# 3     2020-11-06 19:15:00       54.777778     76.383333
# 4     2020-11-06 20:15:00       53.879167     78.233333
# ...                   ...             ...           ...
# 1758  2021-03-15 09:21:00       41.026667     72.850000
# 1759  2021-03-15 10:21:00       40.480000     74.316667
# 1760  2021-03-15 11:21:00       40.091667     76.100000
# 1761  2021-03-15 12:21:00       40.087500     75.900000
# 1762  2021-03-15 13:21:00       40.087500     76.900000
#
# [1761 rows x 3 columns]

# %%
ambient_df = df[['Date_Ambient', 'Temp_Ambient', 'RH_Ambient']].copy()
ambient_df = ambient_df.dropna()
ambient_df
# Out:
#              Date_Ambient  Temp_Ambient  RH_Ambient
# 0     2020-11-06 16:00:00         72.75       70.17
# 1     2020-11-06 17:00:00         71.46       71.29
# 2     2020-11-06 18:00:00         66.53       73.98
# 3     2020-11-06 19:00:00         62.24       75.76
# 4     2020-11-06 20:00:00         59.75       79.23
# ...                   ...           ...         ...
# 3052  2021-03-13 20:00:00         46.03       38.65
# 3053  2021-03-13 21:00:00         42.10       43.93
# 3054  2021-03-13 22:00:00         41.25       47.20
# 3055  2021-03-13 23:00:00         38.88       48.17
# 3056  2021-03-14 00:00:00         37.79       54.06
#
# [3057 rows x 3 columns]

# %%
co2_df = df[['Date_CO2', 'CO2_Plenum', 'CO2_Headspace']].copy()
co2_df = co2_df.dropna()
co2_df
# Out:
#                  Date_CO2  CO2_Plenum  CO2_Headspace
# 0     2020-11-06 15:44:00    0.536337       0.528224
# 1     2020-11-06 16:44:00    0.545077       0.501610
# 2     2020-11-06 17:44:00    0.533929       0.512470
# 3     2020-11-06 18:44:00    0.563265       0.493393
# 4     2020-11-06 19:44:00    0.557900       0.502317
# ...                   ...         ...            ...
# 1847  2021-03-12 15:38:00    0.552928       0.496952
# 1848  2021-03-12 16:38:00    0.560020       0.505248
# 1849  2021-03-12 17:38:00    0.568760       0.507498
# 1850  2021-03-12 18:38:00    0.564155       0.514302
# 1851  2021-03-12 19:38:00    0.569310       0.517286
#
# [1852 rows x 3 columns]

# %%
co2_df_1 = co2_df.loc[co2_df['Date_CO2'] < datetime(2020, 12, 11)]

# %%
co2_df_2 = co2_df.loc[co2_df['Date_CO2'] > datetime(2020, 12, 11)]

# %%
fig, ax = plt.subplots(dpi=150)
ax.plot(date_grain_df.Date_Grain.to_numpy(), date_grain_df.Grain_Avg_Temp.to_numpy(), 'r--')
ax.plot(date_grain_df.Date_Grain.to_numpy(), date_grain_df.Grain_Avg_RH.to_numpy(), 'b')

# %%
fig, ax = plt.subplots(dpi=250)
# line1 = ax.plot(co2_df.Date_CO2.to_numpy(), co2_df.CO2_Plenum.to_numpy(), color='#cc6408', label='CO2_Plenum', alpha=0.5) ## helps to dim colors
line1 = ax.plot(co2_df_1.Date_CO2.to_numpy(), co2_df_1.CO2_Plenum.to_numpy(), color='#cc6408', label='CO2_Plenum')
line2 = ax.plot(co2_df_1.Date_CO2.to_numpy(), co2_df_1.CO2_Headspace.to_numpy(), 'blue', label='CO2_Headspace')
line11 = ax.plot(co2_df_2.Date_CO2.to_numpy(), co2_df_2.CO2_Plenum.to_numpy(), color='#cc6408')
line22 = ax.plot(co2_df_2.Date_CO2.to_numpy(), co2_df_2.CO2_Headspace.to_numpy(), 'blue')
ax2 = ax.twinx()
line3 = ax2.plot(date_grain_df.Date_Grain.to_numpy(), date_grain_df.Grain_Avg_Temp.to_numpy(), 'g', label='Grain_Avg_Temp')
# line4 = ax2.plot(date_grain_df.Date_Grain.to_numpy(), date_grain_df.Grain_Avg_RH.to_numpy(), 'brown', label='Grain_Avg_RH')
line5 = ax2.plot(ambient_df.Date_Ambient.to_numpy(), ambient_df.Temp_Ambient.to_numpy(), 'purple', label='Grain_Ambient')
date_form = DateFormatter("%m/%d/%Y")
ax.xaxis.set_major_formatter(date_form)
months = MonthLocator()
ax.xaxis.set_major_locator(months)
fig.suptitle('BIN 13', y=1.1)
ax.set_xlabel('Date')
ax.set_ylabel('$CO_2$ x 1000 ppm');
ax2.set_ylabel('Temperature, $\degree$F');
lns = line5 + line1 + line2 + line3
labs = [l.get_label() for l in lns]
ax.legend(lns, labs, bbox_to_anchor=(0.5, 1.2), loc="upper center", ncol=3);
plt.xlim([datetime(2020, 11, 6), datetime(2021, 3, 5)])
filename = path / 'Bin 13.jpeg'
plt.savefig(filename, bbox_inches='tight')
